# %% [markdown]
# ## Question 1: Convert Celsius to Fahrenheit
#
# Write a Python program that converts a temperature from Celsius to Fahrenheit.
#
# Use the formula:
#
# fahrenheit = (celsius * 9 / 5) + 32
#
# ### Run 1
# Use:
# celsius = 32.0
#
# Display both the Celsius and Fahrenheit temperatures with appropriate units.
# Before running the program, predict the result and identify the arithmetic operations used.

# %%
celsius = 32.0
fahrenheit = (celsius * 9 / 5) + 32
print("Celsius:", celsius, "C")
print("Fahrenheit:", fahrenheit, "F")
# Out:
# Celsius: 32.0 C
# Fahrenheit: 89.6 F

# %% [markdown]
# ####Run 2
# For the second run, celsius = 0.0

# %%
celsius = 0.0
fahrenheit = (celsius * 9 / 5) + 32
print("Celsius:", celsius, "C")
print("Fahrenheit:", fahrenheit, "F")
# Out:
# Celsius: 0.0 C
# Fahrenheit: 32.0 F

# %% [markdown]
# ## Question 2: Simple Interest
#
# Write a Python program to calculate simple interest and the final amount.
#
# Use:
#
# simple_interest = principal * rate * time_years / 100
#
# final_amount = principal + simple_interest
#
# ### Run 1
# principal = 25000
# rate = 6.5
# time_years = 3

# %%
principal = 25000
rate = 6.5
time_years = 3
simple_interest = principal * rate * time_years / 100
final_amount = principal + simple_interest
print("Simple interest:", simple_interest)
print("Finaal Amount:", final_amount)
# Out:
# Simple interest: 4875.0
# Finaal Amount: 29875.0

# %%
principal = 0
rate = 6.5
time_years = 3
simple_interest = principal * rate * time_years / 100
final_amount = principal + simple_interest
print("Simple interest:", simple_interest)
print("Finaal Amount:", final_amount)
# Out:
# Simple interest: 0.0
# Finaal Amount: 0.0

# %% [markdown]
# ## Question 3: Compare Two Numbers
#
# Write a Python program to compare two numbers and store whether the first number is greater than the second.
#
# ### Run 1
# first_number = 48
# second_number = 35

# %%
first_number = 48
second_number = 35
first_is_greater = first_number > second_number
print("First number:", first_number)
print("Second number:", second_number)
print("Is first number greater?", first_is_greater)
# Out:
# First number: 48
# Second number: 35
# Is first number greater? True

# %%
first_number = 35
second_number = 35
first_is_greater = first_number > second_number
print("First number:", first_number)
print("Second number:", second_number)
print("Is first number greater?", first_is_greater)
# Out:
# First number: 35
# Second number: 35
# Is first number greater? False

# %% [markdown]
# ## Question 4: Average of Three Marks
#
# Write a Python program to calculate the total and average of three marks.
#
# Use:
#
# total_marks = mark_1 + mark_2 + mark_3
#
# average_marks = total_marks / 3
#
# ### Run 1
# mark_1 = 72
# mark_2 = 81
# mark_3 = 69

# %%
mark_1 = 72
mark_2 = 81
mark_3 = 69
total_marks = mark_1 + mark_2 + mark_3
average_marks = total_marks / 3
print("Total marks:", total_marks)
print("Average marks:", average_marks)
# Out:
# Total marks: 222
# Average marks: 74.0

# %%
mark_1 = 0
mark_2 = 0
mark_3 = 0
total_marks = mark_1 + mark_2 + mark_3
average_marks = total_marks / 3
print("Total marks:", total_marks)
print("Average marks:", average_marks)
# Out:
# Total marks: 0
# Average marks: 0.0

# %% [markdown]
# ## Question 5: Convert Seconds into Hours, Minutes and Seconds
#
# Write a Python program to convert total seconds into hours, minutes and seconds using floor division // and modulus %.
#
# ### Run 1
# total_seconds = 7384

# %%
total_seconds = 7384
hours = total_seconds // 3600
remaining_seconds = total_seconds % 3600
minutes = remaining_seconds // 60
seconds = remaining_seconds % 60
print("Hours:", hours)
print("Minutes:", minutes)
print("Secomd:", seconds)
# Out:
# Hours: 2
# Minutes: 3
# Secomd: 4

# %%
total_seconds = 59
hours = total_seconds // 3600
remaining_seconds = total_seconds % 3600
minutes = remaining_seconds // 60
seconds = remaining_seconds % 60
print("Hours:", hours)
print("Minutes:", minutes)
print("Secomd:", seconds)
# Out:
# Hours: 0
# Minutes: 0
# Secomd: 59

# %% [markdown]
# ## Question 6: Calculate Discount and Final Price
#
# Write a Python program to calculate the discount amount and final price.
#
# Use:
#
# discount_amount = price * discount_rate
#
# final_price = price - discount_amount
#
# ### Run 1
# price = 2400.0
# discount_rate = 0.15

# %%
price = 2400.0
discount_rate = 0.15
discount_amount = price * discount_rate
final_prices = price - discount_amount
print("Original price:", price)
print("Discount Amount:", discount_amount)
print("Final price:", final_prices)
# Out:
# Original price: 2400.0
# Discount Amount: 360.0
# Final price: 2040.0

# %%
price = 2400.0
discount_rate = 0
discount_amount = price * discount_rate
final_prices = price - discount_amount
print("Original price:", price)
print("Discount Amount:", discount_amount)
print("Final price:", final_prices)
# Out:
# Original price: 2400.0
# Discount Amount: 0.0
# Final price: 2400.0

# %% [markdown]
# ## Question 7: Swap Two Values
#
# Write a Python program to swap two values without using a temporary variable.
#
# Use:
#
# first_value, second_value = second_value, first_value
#
# ### Run 1
# first_value = 12
# second_value = 45

# %%
first_value = 12
second_value = 45
print("Before Swapping:")
print("First value:", first_value)
print("Second value:", second_value)
first_value, second_value = second_value, first_value
print ("After swapping:")
print("First value:", first_value)
print("Second value:", second_value)
# Out:
# Before Swapping:
# First value: 12
# Second value: 45
# After swapping:
# First value: 45
# Second value: 12

# %%
first_value = 12
second_value = 12
print("Before Swapping:")
print("First value:", first_value)
print("Second value:", second_value)
first_value, second_value = second_value, first_value
print ("After swapping:")
print("First value:", first_value)
print("Second value:", second_value)
# Out:
# Before Swapping:
# First value: 12
# Second value: 12
# After swapping:
# First value: 12
# Second value: 12

# %% [markdown]
# ## Question 8: Evaluate an Expression Using Operator Precedence
#
# Write a Python program to evaluate:
#
# a + b * c
#
# First calculate and store b * c in multiplication_result.
# Then add a to calculate final_result.
#
# ### Run 1
# a = 8
# b = 3
# c = 2

# %%
a = 8
b = 3
c = 2
multiplication_result = b * c
final_result = a + multiplication_result
print("multiplication result:", multiplication_result)
print("Final Result:", final_result)
# Out:
# multiplication result: 6
# Final Result: 14

# %%
a = 9
b = 3
c = 2
multiplication_result = b * c
final_result = a + multiplication_result
print("multiplication result:", multiplication_result)
print("Final Result:", final_result)
# Out:
# multiplication result: 6
# Final Result: 15
